# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd

# %%
data = pd.read_csv("celsius.csv")

# %%
data.head()
# Out:
#    celsius  fahrenheit
# 0      -40       -40.0
# 1      -10        14.0
# 2        0        32.0
# 3        8        46.4
# 4       15        59.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   celsius     7 non-null      int64
#  1   fahrenheit  7 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 244.0 bytes

# %%
import seaborn as sb

# %%
import seaborn as sb

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x=data['celsius'], y=data['fahrenheit'])

# %%
X = data["celsius"]
Y = data["fahrenheit"]

# %%
plt.scatter(x=data['celsius'], y=data['fahrenheit'], data = data, hue="fahrenheit")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22796\1466557537.py in ?()
# ----> 1 plt.scatter(x=data['celsius'], y=data['fahrenheit'], data = data, hue="fahrenheit")
#
# c:\Users\I.BERNARD\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py in ?(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3813     plotnonfinite: bool = False,
#    3814     data=None,
#    3815     **kwargs,
#    3816 ) -> PathCollection:
# -> 3817     __ret = gca().scatter(
#    3818         x,
#    3819         y,
#    3820         s=s,
#
# c:\Users\I.BERNARD\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py in ?(ax, data, *args, **kwargs)
#    1488                 *map(sanitize_sequence, args),
# ...

# %%
sb.scatterplot(x="celsius", y="fahrenheit", data=data,  hue="fahrenheit")
# Out:
# <Axes: xlabel='celsius', ylabel='fahrenheit'>
